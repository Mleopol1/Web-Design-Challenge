# %%
import pandas as pd
import os

# %%
csv = pd.read_csv('cities.csv')
df = pd.DataFrame(csv)
df.rename(columns = {'Unnamed: 0': 'City_ID'}, inplace = True)
df.set_index('City_ID', inplace = True)
df
# Out:
#                    City      Lat       Lng  Max Temp (F)  Humidity  \
# City_ID
# 0               Northam  51.0333   -4.2167         61.61        94
# 1        Port Macquarie -31.4333  152.9167         64.89       100
# 2               Ushuaia -54.8000  -68.3000         40.66        87
# 3                 Kapaa  22.0752 -159.3190         76.98        86
# 4             Cape Town -33.9258   18.4232         64.81        72
# ...                 ...      ...       ...           ...       ...
# 575             Samarai -10.6167  150.6667         83.62        75
# 576              Shache  38.4167   77.2406         53.71        38
# 577               Sabha  27.0377   14.4283         70.90        44
# 578          Kabardinka  44.6514   37.9428         59.25        81
# 579           Zavetnoye  47.1194   43.8903         52.56        71
#
#          Cloudiness  Wind Speed Country        Date
# City_ID
# 0               100        8.75      GB  1666215251
# ...

# %%
html_data = df.to_html(classes='table table-stripped')
html_data
# Out:
# '<table border="1" class="dataframe table table-stripped">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City</th>\n      <th>Lat</th>\n      <th>Lng</th>\n      <th>Max Temp (F)</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed</th>\n      <th>Country</th>\n      <th>Date</th>\n    </tr>\n    <tr>\n      <th>City_ID</th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n      <th></th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>Northam</td>\n      <td>51.0333</td>\n      <td>-4.2167</td>\n      <td>61.61</td>\n      <td>94</td>\n      <td>100</td>\n      <td>8.75</td>\n      <td>GB</td>\n      <td>1666215251</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>Port Macquarie</td>\n      <td>-31.4333</td>\n      <td>152.9167</td>\n      <td>64.89</td>\n      <td>100</td>\n      <td>100</td>\n      <td>5.75</t
# ...
